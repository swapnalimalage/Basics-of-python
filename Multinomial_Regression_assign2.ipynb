# %% [markdown]
# <a href="https://colab.research.google.com/github/swapnalimalage/Basics-of-python/blob/main/Multinomial_Regression_assign2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### Multinomial Regression ####
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
loan= pd.read_csv(r'/content/loan.csv')

# %%
loan.describe()
loan.loan_amnt.value_counts()
loan.drop(columns =['url'])
# Out:
#             id  member_id  ...  total_bc_limit  total_il_high_credit_limit
# 0      1077501    1296599  ...             NaN                         NaN
# 1      1077430    1314167  ...             NaN                         NaN
# 2      1077175    1313524  ...             NaN                         NaN
# 3      1076863    1277178  ...             NaN                         NaN
# 4      1075358    1311748  ...             NaN                         NaN
# ...        ...        ...  ...             ...                         ...
# 11322   816456     984045  ...             NaN                         NaN
# 11323   802048    1007670  ...             NaN                         NaN
# 11324   816414    1024145  ...             NaN                         NaN
# 11325   816399    1024129  ...             NaN                         NaN
# 11326   816395    1024125  ...             NaN                         NaN
#
# [11327 rows x 110 columns]

# %%
l1 = loan.iloc[:, 0:9]
l1.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade'],
#       dtype='object')

# %%
# Boxplot of independent variable distribution for each category of choice 
sns.boxplot(x = "id", y = "member_id", data = l1)

# %%
sns.boxplot(x = "id", y = "loan_amnt", data = l1)
